# %% [markdown]
# # Sign of transverse impact parameter d<sub>0</sub>

# %% [markdown]
# 1. We define the transverse impact parameter d<sub>0</sub> as the distance of closest approach of the track __to the z-axis__.
#   - If defined w.r.t the beam axis, we need correction for the beam movement.
#   - If defined w.r.t the primary vertex, which is a 3D point, the equation becomes far more complicated.
#
# 2. We assume that the magnetic field is pointing along the positive z-axis. A track with negative charge goes counter-clockwise, i.e. it has increasing &#981;(r).
#
# 3. We also define the radius of curvature R as:
#
# \begin{align}
# R = -\frac{p_{\mathrm{T}}}{0.003 q B}\,[\mathrm{cm}]
# \end{align}
#
# where q is the charge of the track, and B is the magnetic field strength in Tesla. R is positive if the track goes counter-clockwise.
#
# 4. The sign of d<sub>0</sub> needs to satisfy the following two requirements:
#
#   - The sign should agree with the sign of $(\vec{r} \times \vec{p})_{z}$ at the point of closest approach, where $\vec{r}$ is the point of closest approach from the origin. This also means that the sign of d<sub>0</sub> is positive if the direction of the track at d<sub>0</sub> is counter-clockwise w.r.t. the origin.
#   - The d<sub>0</sub> is continuous such that the sign changes from positive to negative (or vice versa) at d<sub>0</sub> = 0.
#
# 5. For a straight track with infinite p<sub>T</sub>, the d<sub>0</sub> with the correct sign can be obtained from the following equation:
#
# \begin{align}
# d_{0} = x_{v} \sin{\phi} - y_{v} \cos{\phi}
# \end{align}
#
# where (x<sub>v</sub>, y<sub>v</sub>) are the vertex coordinates and &#981; is the azimuthal angle of the track $\vec{p}_{\mathrm{T}}$ at the vertex. If we express (x<sub>v</sub>, y<sub>v</sub>) in polar coordinates (R<sub>v</sub>, &#981;<sub>v</sub>), we get the equation for the sign of d<sub>0</sub> for a straight track:
#
# \begin{align}
# \operatorname{sign}(d_{0}) &= \operatorname{sign}(\cos{\phi_{v}} \sin{\phi} - \sin{\phi_{v}} \cos{\phi}) \\
#       &= \operatorname{sign}(\sin(\phi - \phi_{v}))
# \end{align}
#
# 6. For a curved track, it's more complicated. The absolute value of d<sub>0</sub> can be obtained from the following equation:
#
# \begin{align}
# \left|d_{0}\right| = \left|{|R| - \sqrt{{x_{c}}^2 + {y_{c}}^2}}\right|
# %d_{0} = R - \sqrt{{x_{c}}^2 + {y_{c}}^2}
# \end{align}
#
# where (x<sub>c</sub>, y<sub>c</sub>) are the coordinates of the center of the helix in the x-y plane. They are related to (x<sub>v</sub>, y<sub>v</sub>) by the following equations:
#
# \begin{align}
# x_{c} &= x_{v} - R \sin{\phi} \\
# y_{c} &= y_{v} + R \cos{\phi}
# \end{align}
#
# 7. Finally, we find the sign of d<sub>0</sub>, which depends on (x<sub>v</sub>, y<sub>v</sub>), &#981; and R.
#
#   - Find the sign of d<sub>0</sub> assuming a straight track, called S<sub>R&infin;</sub>.
#   - Find the sign of R. If the sign of R is opposite to S<sub>R&infin;</sub>, the sign of d<sub>0</sub> will be S<sub>R&infin;</sub>; if the sign of R is the same as S<sub>R&infin;</sub>, the sign of d<sub>0</sub> will change as d<sub>0</sub> goes through zero.
#   - Find the R for which d<sub>0</sub> goes through zero, called R\*. If |R| of the track is larger than |R\*|, the sign of d<sub>0</sub> will be S<sub>R&infin;</sub>; else, the sign of d<sub>0</sub> will be opposite to S<sub>R&infin;</sub>.
#
# R\* can be obtained from the following equation:
#
# \begin{align}
# R^* = \frac{\sqrt{{x_{v}}^2 + {y_{v}}^2}}{2 \sin(\phi - \phi_{v})}
# \end{align}

# %%
import numpy as np
import matplotlib.pyplot as plt

step = 1.0
x = np.arange(-120+1, 120, step)
y = np.arange(-120+1, 120, step)
X, Y = np.meshgrid(x, y)

phi = 135
phi_rad = np.deg2rad(phi)
Z = X * np.sin(phi_rad) - Y * np.cos(phi_rad)
Z = np.sign(Z)

# %%
fig, ax = plt.subplots(figsize=(8,6.5))
CS = ax.contourf(X, Y, Z, cmap=plt.cm.coolwarm)
cbar = fig.colorbar(CS)
ax.axhline(y=0, alpha=0.5, color='white')
ax.axvline(x=0, alpha=0.5, color='white')
ax.set_title(r'Sign of $d_0$ for a straight track with $\phi = %i^{\circ}$' % phi, fontsize=16)
ax.set_xlabel(r'$x_v$ [cm]', fontsize=14)
ax.set_ylabel(r'$y_v$ [cm]', fontsize=14)

plt.show()

# %%
x = np.arange(-180+1, 180, step)
x = np.deg2rad(x)
xv, yv = 50, 50
y1 = xv * np.sin(x) - yv * np.cos(x)
y1 = np.sign(y1)
xv, yv = -50, 50
y2 = xv * np.sin(x) - yv * np.cos(x)
y2 = np.sign(y2)
xv, yv = 50, -50
y3 = xv * np.sin(x) - yv * np.cos(x)
y3 = np.sign(y3)
xv, yv = -50, -50
y4 = xv * np.sin(x) - yv * np.cos(x)
y4 = np.sign(y4)

# %%
fig, axs = plt.subplots(2,2, figsize=(8,6.5), constrained_layout=True)

fig.suptitle(r'Sign of $d_0$ vs $\phi$ for a straight track', fontsize=16)

# 1st quadrant
axs[0,1].plot(x, y1)
axs[0,1].set_title(r'$(x_v,y_v) = (50,50)$', fontsize=16)
axs[0,1].set_xlabel(r'$\phi$', fontsize=14)
axs[0,1].set_ylabel(r'sign of $d_0$', fontsize=14)
# 2nd quadrant
axs[0,0].plot(x, y2)
axs[0,0].set_title(r'$(x_v,y_v) = (-50,50)$', fontsize=16)
axs[0,0].set_xlabel(r'$\phi$', fontsize=14)
axs[0,0].set_ylabel(r'sign of $d_0$', fontsize=14)
# 3rd quadrant
axs[1,0].plot(x, y3)
axs[1,0].set_title(r'$(x_v,y_v) = (50,-50)$', fontsize=16)
axs[1,0].set_xlabel(r'$\phi$', fontsize=14)
axs[1,0].set_ylabel(r'sign of $d_0$', fontsize=14)
# 4th quadrant
axs[1,1].plot(x, y4)
axs[1,1].set_title(r'$(x_v,y_v) = (-50,-50)$', fontsize=16)
axs[1,1].set_xlabel(r'$\phi$', fontsize=14)
axs[1,1].set_ylabel(r'sign of $d_0$', fontsize=14)

plt.show()

# %%
x = np.arange(-180+1, 180, step)
x = np.deg2rad(x)
xv, yv = 50, 50
x1 = np.sin(x - np.arctan2(yv, xv))
y1 = xv * np.sin(x) - yv * np.cos(x)
y1 = np.sign(y1)
xv, yv = -50, 50
x2 = np.sin(x - np.arctan2(yv, xv))
y2 = xv * np.sin(x) - yv * np.cos(x)
y2 = np.sign(y2)
xv, yv = 50, -50
x3 = np.sin(x - np.arctan2(yv, xv))
y3 = xv * np.sin(x) - yv * np.cos(x)
y3 = np.sign(y3)
xv, yv = -50, -50
x4 = np.sin(x - np.arctan2(yv, xv))
y4 = xv * np.sin(x) - yv * np.cos(x)
y4 = np.sign(y4)

# %%
fig, axs = plt.subplots(2,2, figsize=(8,6.5), constrained_layout=True)

fig.suptitle(r'Sign of $d_0$ vs $\sin(\phi-\phi_v)$ for a straight track', fontsize=16)

# 1st quadrant
axs[0,1].plot(x1, y1)
axs[0,1].set_title(r'$(x_v,y_v) = (50,50)$', fontsize=16)
axs[0,1].set_xlabel(r'$\sin(\phi-\phi_v)$', fontsize=14)
axs[0,1].set_ylabel(r'sign of $d_0$', fontsize=14)
# 2nd quadrant
axs[0,0].plot(x2, y2)
axs[0,0].set_title(r'$(x_v,y_v) = (-50,50)$', fontsize=16)
axs[0,0].set_xlabel(r'$\sin(\phi-\phi_v)$', fontsize=14)
axs[0,0].set_ylabel(r'sign of $d_0$', fontsize=14)
# 3rd quadrant
axs[1,0].plot(x3, y3)
axs[1,0].set_title(r'$(x_v,y_v) = (50,-50)$', fontsize=16)
axs[1,0].set_xlabel(r'$\sin(\phi-\phi_v)$', fontsize=14)
axs[1,0].set_ylabel(r'sign of $d_0$', fontsize=14)
# 4th quadrant
axs[1,1].plot(x4, y4)
axs[1,1].set_title(r'$(x_v,y_v) = (-50,-50)$', fontsize=16)
axs[1,1].set_xlabel(r'$\sin(\phi-\phi_v)$', fontsize=14)
axs[1,1].set_ylabel(r'sign of $d_0$', fontsize=14)

plt.show()

# %% [markdown]
# ### Visualization

# %%
xv, yv = 50, 50
phi = 135
invPt = -0.5

phi_rad = np.deg2rad(phi)
R = -(1.0/(0.003 * 3.8 * invPt))
xc, yc = xv - R * np.sin(phi_rad), yv + R * np.cos(phi_rad)

R1 = -1 * R
xc1, yc1 = xv - R1 * np.sin(phi_rad), yv + R1 * np.cos(phi_rad)

R2 = np.sqrt(xv*xv + yv*yv) / (2 * np.sin(phi_rad - np.arctan2(yv, xv)) + 1e-7)
xc2, yc2 = xv - R2 * np.sin(phi_rad), yv + R2 * np.cos(phi_rad)

simC = 1./(2*R) 
simCstar = np.sin(phi_rad - np.arctan2(yv, xv)) / np.sqrt(xv*xv + yv*yv)
d0 = np.abs(np.abs(R) - np.sqrt(xc*xc + yc*yc))
d0_sign = np.sign(simCstar)
if ((simCstar < 0) and (simC < simCstar)) or ((simCstar > 0) and (simC > simCstar)):
  d0_sign *= -1
d0 *= d0_sign

d0_314 = R - (np.sign(R) * np.hypot(xc, yc))

print R, R1, R2, d0, d0_314
# Out:
# 175.438596491 -175.438596491 35.35533729156052 70.71067811865476 70.71067811865476

# %%
from matplotlib.patches import Circle
vertex = Circle((xv, yv), 3, color='k')
center = Circle((xc, yc), 3, color='r')
circ = Circle((xc, yc), R, color='r', fill=False)
center1 = Circle((xc1, yc1), 3, color='b')
circ1 = Circle((xc1, yc1), R1, color='b', fill=False)
center2 = Circle((xc2, yc2), 3, color='g')
circ2 = Circle((xc2, yc2), R2, color='g', fill=False)

fig, ax = plt.subplots(figsize=(8,8))
ax.add_artist(vertex)
ax.add_artist(center)
ax.add_artist(circ)
ax.add_artist(center1)
ax.add_artist(circ1)
ax.add_artist(center2)
ax.add_artist(circ2)
ax.axhline(y=0, alpha=0.5, color='black')
ax.axvline(x=0, alpha=0.5, color='black')
ax.set_xlim((-300, 300))
ax.set_ylim((-300, 300))

plt.show()

# %%
xv, yv = 50, 50
phi = 45 + 190
invPt = -0.5

phi_rad = np.deg2rad(phi)
R = -(1.0/(0.003 * 3.8 * invPt))
xc, yc = xv - R * np.sin(phi_rad), yv + R * np.cos(phi_rad)

R1 = -1 * R
xc1, yc1 = xv - R1 * np.sin(phi_rad), yv + R1 * np.cos(phi_rad)

R2 = np.sqrt(xv*xv + yv*yv) / (2 * np.sin(phi_rad - np.arctan2(yv, xv)) + 1e-7)
xc2, yc2 = xv - R2 * np.sin(phi_rad), yv + R2 * np.cos(phi_rad)

simC = 1./(2*R) 
simCstar = np.sin(phi_rad - np.arctan2(yv, xv)) / np.sqrt(xv*xv + yv*yv)
d0 = np.abs(np.abs(R) - np.sqrt(xc*xc + yc*yc))
d0_sign = np.sign(simCstar)
if ((simCstar < 0) and (simC < simCstar)) or ((simCstar > 0) and (simC > simCstar)):
  d0_sign *= -1
d0 *= d0_sign

d0_314 = R - (np.sign(R) * np.hypot(xc, yc))

print R, R1, R2, d0, d0_314
# Out:
# 175.438596491 -175.438596491 -203.6033416216358 -24.77889809334428 -24.77889809334431

# %%
from matplotlib.patches import Circle
vertex = Circle((xv, yv), 3, color='k')
center = Circle((xc, yc), 3, color='r')
circ = Circle((xc, yc), R, color='r', fill=False)
center1 = Circle((xc1, yc1), 3, color='b')
circ1 = Circle((xc1, yc1), R1, color='b', fill=False)
center2 = Circle((xc2, yc2), 3, color='g')
circ2 = Circle((xc2, yc2), R2, color='g', fill=False)

fig, ax = plt.subplots(figsize=(8,8))
ax.add_artist(vertex)
ax.add_artist(center)
ax.add_artist(circ)
ax.add_artist(center1)
ax.add_artist(circ1)
ax.add_artist(center2)
ax.add_artist(circ2)
ax.axhline(y=0, alpha=0.5, color='black')
ax.axvline(x=0, alpha=0.5, color='black')
ax.set_xlim((-300, 300))
ax.set_ylim((-300, 300))

plt.show()

# %%
xv, yv = 50, 50
phi = 45 + 170
invPt = -0.5

phi_rad = np.deg2rad(phi)
R = -(1.0/(0.003 * 3.8 * invPt))
xc, yc = xv - R * np.sin(phi_rad), yv + R * np.cos(phi_rad)

R1 = -1 * R
xc1, yc1 = xv - R1 * np.sin(phi_rad), yv + R1 * np.cos(phi_rad)

R2 = np.sqrt(xv*xv + yv*yv) / (2 * np.sin(phi_rad - np.arctan2(yv, xv)) + 1e-7)
xc2, yc2 = xv - R2 * np.sin(phi_rad), yv + R2 * np.cos(phi_rad)

simC = 1./(2*R) 
simCstar = np.sin(phi_rad - np.arctan2(yv, xv)) / np.sqrt(xv*xv + yv*yv)
d0 = np.abs(np.abs(R) - np.sqrt(xc*xc + yc*yc))
d0_sign = np.sign(simCstar)
if ((simCstar < 0) and (simC < simCstar)) or ((simCstar > 0) and (simC > simCstar)):
  d0_sign *= -1
d0 *= d0_sign

d0_314 = R - (np.sign(R) * np.hypot(xc, yc))

print R, R1, R2, d0, d0_314
# Out:
# 175.438596491 -175.438596491 203.60322437117784 -1.9602680482627477 -1.9602680482627477

# %%
from matplotlib.patches import Circle
vertex = Circle((xv, yv), 3, color='k')
center = Circle((xc, yc), 3, color='r')
circ = Circle((xc, yc), R, color='r', fill=False)
center1 = Circle((xc1, yc1), 3, color='b')
circ1 = Circle((xc1, yc1), R1, color='b', fill=False)
center2 = Circle((xc2, yc2), 3, color='g')
circ2 = Circle((xc2, yc2), R2, color='g', fill=False)

fig, ax = plt.subplots(figsize=(8,8))
ax.add_artist(vertex)
ax.add_artist(center)
ax.add_artist(circ)
ax.add_artist(center1)
ax.add_artist(circ1)
ax.add_artist(center2)
ax.add_artist(circ2)
ax.axhline(y=0, alpha=0.5, color='black')
ax.axvline(x=0, alpha=0.5, color='black')
ax.set_xlim((-300, 300))
ax.set_ylim((-300, 300))

plt.show()

# %%
xv, yv = 100, 100
phi = 135
invPt = -1.5

phi_rad = np.deg2rad(phi)
R = -(1.0/(0.003 * 3.8 * invPt))
xc, yc = xv - R * np.sin(phi_rad), yv + R * np.cos(phi_rad)

R1 = -1 * R
xc1, yc1 = xv - R1 * np.sin(phi_rad), yv + R1 * np.cos(phi_rad)

R2 = np.sqrt(xv*xv + yv*yv) / (2 * np.sin(phi_rad - np.arctan2(yv, xv)) + 1e-7)
xc2, yc2 = xv - R2 * np.sin(phi_rad), yv + R2 * np.cos(phi_rad)

simC = 1./(2*R) 
simCstar = np.sin(phi_rad - np.arctan2(yv, xv)) / np.sqrt(xv*xv + yv*yv)
d0 = np.abs(np.abs(R) - np.sqrt(xc*xc + yc*yc))
d0_sign = np.sign(simCstar)
if ((simCstar < 0) and (simC < simCstar)) or ((simCstar > 0) and (simC > simCstar)):
  d0_sign *= -1
d0 *= d0_sign

d0_314 = R - (np.sign(R) * np.hypot(xc, yc))

print R, R1, R2, d0, d0_314
# Out:
# 58.4795321637 -58.4795321637 70.71067458312103 -24.46229190982413 -24.46229190982413

# %%
from matplotlib.patches import Circle
vertex = Circle((xv, yv), 3, color='k')
center = Circle((xc, yc), 3, color='r')
circ = Circle((xc, yc), R, color='r', fill=False)
center1 = Circle((xc1, yc1), 3, color='b')
circ1 = Circle((xc1, yc1), R1, color='b', fill=False)
center2 = Circle((xc2, yc2), 3, color='g')
circ2 = Circle((xc2, yc2), R2, color='g', fill=False)

fig, ax = plt.subplots(figsize=(8,8))
ax.add_artist(vertex)
ax.add_artist(center)
ax.add_artist(circ)
ax.add_artist(center1)
ax.add_artist(circ1)
ax.add_artist(center2)
ax.add_artist(circ2)
ax.axhline(y=0, alpha=0.5, color='black')
ax.axvline(x=0, alpha=0.5, color='black')
ax.set_xlim((-300, 300))
ax.set_ylim((-300, 300))

plt.show()

# %% [markdown]
# ### Numerical stability

# %%
step = 1e6
x = np.arange(1, 4e10, step)
y = x/(0.003 * 3.8)  # R
d0 = 1e-4  # micron
y1 = y + d0
y2 = y1 - y

print x.dtype, y.dtype, y1.dtype
# Out:
# float64 float64 float64

# %%
fig, ax = plt.subplots(figsize=(8,6.5))
ax.plot(x, y2)
#ax.plot(y, y2)
ax.set_title(r'Numerical stability ($\epsilon$ = 2.22e-16)', fontsize=16)
ax.set_xlabel(r'$p_{\mathrm{T}}$ [GeV]', fontsize=16)
ax.set_ylabel(r'a - b', fontsize=16)
ax.set_ylim(-d0*3, d0*3)

plt.show()

# %%
step = 1e18
x = np.arange(1, 1e22, step)
y = x/(0.003 * 3.8)  # R
y1 = 50 - y
y2 = 50 + y
#y3 = np.hypot(y1, y2)
y3 = np.sqrt(np.square(y1) + np.square(y2))

print x.dtype, y.dtype, y1.dtype
# Out:
# float64 float64 float64

# %%
fig, ax = plt.subplots(figsize=(8,6.5))
ax.plot(x, y3)
#ax.plot(y, y2)
ax.set_title(r'Numerical stability ($\epsilon$ = 2.22e-16)', fontsize=16)
ax.set_xlabel(r'$p_{\mathrm{T}}$ [GeV]', fontsize=16)
ax.set_ylabel(r'sqrt(a**2 + b**2)', fontsize=16)
#ax.set_ylim(-d0*3, d0*3)

plt.show()

# %% [markdown]
# ### Straight line approximation

# %%
xv, yv = 50, 50
phi = 35

step = 1e1
x = np.arange(1, 5e2, step)
R = x/(0.003 * 3.8)

phi_rad = np.deg2rad(phi)
xc, yc = xv - R * np.sin(phi_rad), yv + R * np.cos(phi_rad)

d0 = np.abs(np.abs(R) - np.sqrt(xc*xc + yc*yc))
d0 *= -1
d0_simple = xv * np.sin(phi_rad) - yv * np.cos(phi_rad)
d0_simple = np.full_like(x, d0_simple)

# %%
fig, ax = plt.subplots(figsize=(8,6.5))
ax.plot(R, d0_simple, 'k')
ax.plot(R, d0, 'b')

ax.legend(['Approximation', 'Exact'], fontsize=16)

ax.set_title('Straight-line approximation break-down \nfor ' + r'$(x_{v},y_{v})$ = (50,50), $\phi = 35^{\circ}$', fontsize=16)
ax.set_xlabel(r'$R$ [cm]', fontsize=16)
ax.set_ylabel(r'$d_{0}$ [cm]', fontsize=16)
ax.set_ylim(-35,0)

plt.show()

# %%
phi = 35
invPt = -1/200.

step = 1
x = np.arange(1, 5e1, step)
Rv = x/(0.003 * 3.8)

phi_v = np.deg2rad(phi+0)
xv, yv = Rv * np.cos(phi_v), Rv * np.sin(phi_v)

phi_rad = np.deg2rad(phi)
R = -(1.0/(0.003 * 3.8 * invPt))
xc, yc = xv - R * np.sin(phi_rad), yv + R * np.cos(phi_rad)

d0 = np.abs(np.abs(R) - np.sqrt(xc*xc + yc*yc))
d0 *= -1
d0_simple = xv * np.sin(phi_rad) - yv * np.cos(phi_rad)

# %%
fig, ax = plt.subplots(figsize=(8,6.5))
ax.plot(Rv, d0_simple, 'k')
ax.plot(Rv, d0, 'b')

ax.legend(['Approximation', 'Exact'], fontsize=16)

ax.set_title('Straight-line approximation break-down\n' + r'$p_{\mathrm{T}}$ = 200, $\phi = \phi_{v} = 35^{\circ}$', fontsize=16)
ax.set_xlabel(r'$R_{v} = \sqrt{{x_{v}}^2 + {y_{v}}^2}$ [cm]', fontsize=16)
ax.set_ylabel(r'$d_{0}$ [cm]', fontsize=16)
#ax.set_ylim(-35,0)

plt.show()

# %%
xv, yv = 50, 50
phi = 135
invPt = -1/3.

phi_rad = np.deg2rad(phi)
R = -(1.0/(0.003 * 3.8 * invPt))
xc, yc = xv - R * np.sin(phi_rad), yv + R * np.cos(phi_rad)

R1 = -1 * R
xc1, yc1 = xv - R1 * np.sin(phi_rad), yv + R1 * np.cos(phi_rad)

# %%
from matplotlib.patches import Circle
origin = Circle((0., 0.), 3, color='k')
vertex = Circle((xv, yv), 3, color='m')
center = Circle((xc, yc), 3, color='r')
circ = Circle((xc, yc), R, color='r', fill=False)
center1 = Circle((xc1, yc1), 3, color='b')
circ1 = Circle((xc1, yc1), R1, color='b', fill=False)

fig, ax = plt.subplots(figsize=(8,8))
ax.add_artist(origin)
ax.add_artist(vertex)
ax.add_artist(center)
ax.add_artist(circ)
ax.add_artist(center1)
ax.add_artist(circ1)
ax.axhline(y=0, alpha=0.5, color='black')
ax.axvline(x=0, alpha=0.5, color='black')
ax.set_xlim((-300, 300))
ax.set_ylim((-300, 300))

plt.show()

# %%
xv, yv = -50, -50
phi = 135
invPt = -1/3.

phi_rad = np.deg2rad(phi)
R = -(1.0/(0.003 * 3.8 * invPt))
xc, yc = xv - R * np.sin(phi_rad), yv + R * np.cos(phi_rad)

R1 = -1 * R
xc1, yc1 = xv - R1 * np.sin(phi_rad), yv + R1 * np.cos(phi_rad)

# %%
from matplotlib.patches import Circle
origin = Circle((0., 0.), 3, color='k')
vertex = Circle((xv, yv), 3, color='m')
center = Circle((xc, yc), 3, color='r')
circ = Circle((xc, yc), R, color='r', fill=False)
center1 = Circle((xc1, yc1), 3, color='b')
circ1 = Circle((xc1, yc1), R1, color='b', fill=False)

fig, ax = plt.subplots(figsize=(8,8))
ax.add_artist(origin)
ax.add_artist(vertex)
ax.add_artist(center)
ax.add_artist(circ)
ax.add_artist(center1)
ax.add_artist(circ1)
ax.axhline(y=0, alpha=0.5, color='black')
ax.axvline(x=0, alpha=0.5, color='black')
ax.set_xlim((-300, 300))
ax.set_ylim((-300, 300))

plt.show()

# %% [markdown]
# ### Misc

# %%
xv, yv = 0.0014285, -0.000187
phi = 45
invPt = -1./3

phi_rad = np.deg2rad(phi)
R = -(1.0/(0.003 * 3.8 * invPt))
xc, yc = xv - R * np.sin(phi_rad), yv + R * np.cos(phi_rad)

print xv, yv, xc, yc, R
# Out:
# 0.0014285 -0.000187 -186.07930339119667 186.0805448911967 263.157894737

# %%
from matplotlib.patches import Circle
vertex = Circle((xv, yv), 3, color='b')
center = Circle((xc, yc), 3, color='r')
circ = Circle((xc, yc), R, color='r', fill=False)

circ1 = Circle((14.847969, 16.108282), 3, color='k')
circ2 = Circle((24.674367, 28.409568), 3, color='k')
circ3 = Circle((32.151066, 38.915103), 3, color='k')
circ4 = Circle((40.988518, 52.981149), 3, color='k')
circ5 = Circle((50.718096, 71.239112), 3, color='k')
circ6 = Circle((59.568498, 91.716253), 3, color='k')

fig, ax = plt.subplots(figsize=(8,8))
ax.add_artist(vertex)
ax.add_artist(center)
ax.add_artist(circ)
ax.add_artist(circ1)
ax.add_artist(circ2)
ax.add_artist(circ3)
ax.add_artist(circ4)
ax.add_artist(circ5)
ax.add_artist(circ6)
ax.axhline(y=0, alpha=0.5, color='black')
ax.axvline(x=0, alpha=0.5, color='black')
ax.set_xlim((-300, 300))
ax.set_ylim((-300, 300))

plt.show()

# %%
xv, yv = 0.0014285, -0.000187
phi = 45
invPt = +1./3

phi_rad = np.deg2rad(phi)
R = -(1.0/(0.003 * 3.8 * invPt))
xc, yc = xv - R * np.sin(phi_rad), yv + R * np.cos(phi_rad)

print xv, yv, xc, yc, R
# Out:
# 0.0014285 -0.000187 186.08216039119668 -186.08091889119672 -263.157894737

# %%
from matplotlib.patches import Circle
vertex = Circle((xv, yv), 3, color='b')
center = Circle((xc, yc), 3, color='r')
circ = Circle((xc, yc), R, color='r', fill=False)

circ1 = Circle((16.268982, 14.915911), 3, color='k')
circ2 = Circle((26.772378, 23.261018), 3, color='k')
circ3 = Circle((41.078959, 33.274895), 3, color='k')
circ4 = Circle((53.192080, 40.713622), 3, color='k')
circ5 = Circle((68.613846, 48.955353), 3, color='k')
circ6 = Circle((95.146654, 60.223489), 3, color='k')

fig, ax = plt.subplots(figsize=(8,8))
ax.add_artist(vertex)
ax.add_artist(center)
ax.add_artist(circ)
ax.add_artist(circ1)
ax.add_artist(circ2)
ax.add_artist(circ3)
ax.add_artist(circ4)
ax.add_artist(circ5)
ax.add_artist(circ6)
ax.axhline(y=0, alpha=0.5, color='black')
ax.axvline(x=0, alpha=0.5, color='black')
ax.set_xlim((-300, 300))
ax.set_ylim((-300, 300))

plt.show()

# %%
xv, yv = 0.0014285, -0.000187
phi = 135
invPt = -1./3

phi_rad = np.deg2rad(phi)
R = -(1.0/(0.003 * 3.8 * invPt))
xc, yc = xv - R * np.sin(phi_rad), yv + R * np.cos(phi_rad)

print xv, yv, xc, yc, R
# Out:
# 0.0014285 -0.000187 -186.0793033911967 -186.0809188911967 263.157894737

# %%
from matplotlib.patches import Circle
vertex = Circle((xv, yv), 3, color='b')
center = Circle((xc, yc), 3, color='r')
circ = Circle((xc, yc), R, color='r', fill=False)

circ1 = Circle((-16.23068, 14.948047), 3, color='k')
circ2 = Circle((-26.70136, 23.363889), 3, color='k')
circ3 = Circle((-40.91184, 33.474059), 3, color='k')
circ4 = Circle((-52.96470, 41.009950), 3, color='k')
circ5 = Circle((-68.32818, 49.348535), 3, color='k')
circ6 = Circle((-94.76830, 60.771614), 3, color='k')

fig, ax = plt.subplots(figsize=(8,8))
ax.add_artist(vertex)
ax.add_artist(center)
ax.add_artist(circ)
ax.add_artist(circ1)
ax.add_artist(circ2)
ax.add_artist(circ3)
ax.add_artist(circ4)
ax.add_artist(circ5)
ax.add_artist(circ6)
ax.axhline(y=0, alpha=0.5, color='black')
ax.axvline(x=0, alpha=0.5, color='black')
ax.set_xlim((-300, 300))
ax.set_ylim((-300, 300))

plt.show()

# %%
xv, yv = 0.0014285, -0.000187
phi = 135
invPt = +1./3

phi_rad = np.deg2rad(phi)
R = -(1.0/(0.003 * 3.8 * invPt))
xc, yc = xv - R * np.sin(phi_rad), yv + R * np.cos(phi_rad)

print xv, yv, xc, yc, R
# Out:
# 0.0014285 -0.000187 186.0821603911967 186.08054489119667 -263.157894737

# %%
from matplotlib.patches import Circle
vertex = Circle((xv, yv), 3, color='b')
center = Circle((xc, yc), 3, color='r')
circ = Circle((xc, yc), R, color='r', fill=False)

circ1 = Circle((-14.81349, 16.137204), 3, color='k')
circ2 = Circle((-24.56583, 28.505722), 3, color='k')
circ3 = Circle((-31.98635, 39.053305), 3, color='k')
circ4 = Circle((-40.76360, 53.153729), 3, color='k')
circ5 = Circle((-50.40865, 71.463937), 3, color='k')
circ6 = Circle((-59.13492, 91.990424), 3, color='k')

fig, ax = plt.subplots(figsize=(8,8))
ax.add_artist(vertex)
ax.add_artist(center)
ax.add_artist(circ)
ax.add_artist(circ1)
ax.add_artist(circ2)
ax.add_artist(circ3)
ax.add_artist(circ4)
ax.add_artist(circ5)
ax.add_artist(circ6)
ax.axhline(y=0, alpha=0.5, color='black')
ax.axvline(x=0, alpha=0.5, color='black')
ax.set_xlim((-300, 300))
ax.set_ylim((-300, 300))

plt.show()

# %%
if False:
  from IPython.display import Image
  Image(format="png", data="...")

# %%
if False:
  import numpy as np
  filename = '../test7/histos_tba_displ.24.npz'
  loaded = np.load(filename)

  the_parameters = loaded['parameters']
  print the_parameters.shape
  y_copy = the_parameters.copy()

  y_pt        = y_copy[:, 0]  # q/pT
  y_phi       = y_copy[:, 1]
  y_eta       = y_copy[:, 2]
  y_vx        = y_copy[:, 3]
  y_vy        = y_copy[:, 4]
  y_vz        = y_copy[:, 5]

  y_dxy_old  = y_vx * np.sin(y_phi) - y_vy * np.cos(y_phi)  # valid for a straight track

  _invPt = y_pt.astype(np.float64, copy=True)  # needs double precision
  _R = -1.0 / (0.003 * 3.811 * _invPt)           # R = -pT/(0.003 q B)  [cm]
  _xc = y_vx - (_R * np.sin(y_phi))    # xc = xv - R sin(phi)
  _yc = y_vy + (_R * np.cos(y_phi))    # yc = yv + R cos(phi)
  _d0 = _R - (np.sign(_R) * np.hypot(_xc, _yc))  # d0 = R - sqrt(xc^2 + yc^2) * sign(R)
  y_dxy = _d0.astype(np.float32, casting='same_kind')

# %%
if False:
  plt.figure(figsize=(8,8))

  with plt.style.context('tdrstyle.mplstyle'):
    my_cmap = plt.cm.viridis
    my_cmap.set_under('w',1)
    plt.hist2d(y_dxy, y_dxy_old, bins=(80,80), range=((-120,120),(-120,120)), vmin=1, cmap=my_cmap)
    plt.xlabel('exact $d_{0}$ [cm]', fontsize=16)
    plt.ylabel('approx $d_{0}$ [cm]', fontsize=16)

  plt.show()
