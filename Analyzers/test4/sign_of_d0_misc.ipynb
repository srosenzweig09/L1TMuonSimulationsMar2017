# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
def my_sign(x):
  return 1.0 * (x >= 0.) - 1.0 * (x < 0.)

# %% [markdown]
# ### Misc (1)

# %%
xv, yv = 0.0014285, -0.000187
phi = 45
invPt = -1./3

phi_rad = np.deg2rad(phi)
R = -(1.0/(0.003 * 3.8 * invPt))
xc, yc = xv - R * np.sin(phi_rad), yv + R * np.cos(phi_rad)

print xv, yv, xc, yc, R
# Out:
# 0.0014285 -0.000187 -186.07930339119667 186.0805448911967 263.157894737

# %%
from matplotlib.patches import Circle
vertex = Circle((xv, yv), 3, color='b')
center = Circle((xc, yc), 3, color='r')
circ = Circle((xc, yc), R, color='r', fill=False)

circ1 = Circle((14.847969, 16.108282), 3, color='k')
circ2 = Circle((24.674367, 28.409568), 3, color='k')
circ3 = Circle((32.151066, 38.915103), 3, color='k')
circ4 = Circle((40.988518, 52.981149), 3, color='k')
circ5 = Circle((50.718096, 71.239112), 3, color='k')
circ6 = Circle((59.568498, 91.716253), 3, color='k')

fig, ax = plt.subplots(figsize=(8,8))
ax.add_artist(vertex)
ax.add_artist(center)
ax.add_artist(circ)
ax.add_artist(circ1)
ax.add_artist(circ2)
ax.add_artist(circ3)
ax.add_artist(circ4)
ax.add_artist(circ5)
ax.add_artist(circ6)
ax.axhline(y=0, alpha=0.5, color='black')
ax.axvline(x=0, alpha=0.5, color='black')
ax.set_xlim((-300, 300))
ax.set_ylim((-300, 300))

plt.show()

# %%
xv, yv = 0.0014285, -0.000187
phi = 45
invPt = +1./3

phi_rad = np.deg2rad(phi)
R = -(1.0/(0.003 * 3.8 * invPt))
xc, yc = xv - R * np.sin(phi_rad), yv + R * np.cos(phi_rad)

print xv, yv, xc, yc, R
# Out:
# 0.0014285 -0.000187 186.08216039119668 -186.08091889119672 -263.157894737

# %%
from matplotlib.patches import Circle
vertex = Circle((xv, yv), 3, color='b')
center = Circle((xc, yc), 3, color='r')
circ = Circle((xc, yc), R, color='r', fill=False)

circ1 = Circle((16.268982, 14.915911), 3, color='k')
circ2 = Circle((26.772378, 23.261018), 3, color='k')
circ3 = Circle((41.078959, 33.274895), 3, color='k')
circ4 = Circle((53.192080, 40.713622), 3, color='k')
circ5 = Circle((68.613846, 48.955353), 3, color='k')
circ6 = Circle((95.146654, 60.223489), 3, color='k')

fig, ax = plt.subplots(figsize=(8,8))
ax.add_artist(vertex)
ax.add_artist(center)
ax.add_artist(circ)
ax.add_artist(circ1)
ax.add_artist(circ2)
ax.add_artist(circ3)
ax.add_artist(circ4)
ax.add_artist(circ5)
ax.add_artist(circ6)
ax.axhline(y=0, alpha=0.5, color='black')
ax.axvline(x=0, alpha=0.5, color='black')
ax.set_xlim((-300, 300))
ax.set_ylim((-300, 300))

plt.show()

# %% [markdown]
# ### Misc (2)

# %%
xv, yv = 50, 50
phi = 135
invPt = -0.5

phi_rad = np.deg2rad(phi)
R = -(1.0/(0.003 * 3.8 * invPt))
xc, yc = xv - R * np.sin(phi_rad), yv + R * np.cos(phi_rad)

R1 = -1 * R
xc1, yc1 = xv - R1 * np.sin(phi_rad), yv + R1 * np.cos(phi_rad)

d0 = R - my_sign(R) * np.sqrt(xc*xc + yc*yc)
xd, yd = d0 * np.sin(phi_rad), -d0 * np.cos(phi_rad)
assert(my_sign(d0) == my_sign(xv*np.sin(phi_rad) - yv*np.cos(phi_rad)))

d0_1 = R1 - my_sign(R1) * np.sqrt(xc1*xc1 + yc1*yc1)
xd1, yd1 = d0_1 * np.sin(phi_rad), -d0_1 * np.cos(phi_rad)
assert(my_sign(d0_1) == my_sign(xv*np.sin(phi_rad) - yv*np.cos(phi_rad)))

print R, xc, yc, d0, xd, yd
print R1, xc1, yc1, d0_1, xd1, yd1
# Out:
# 175.438596491 -74.0538212607978 -74.05382126079779 70.71067811865476 50.00000000000001 50.0
# -175.438596491 174.0538212607978 174.0538212607978 70.71067811865476 50.00000000000001 50.0

# %%
from matplotlib.patches import Circle
vertex = Circle((xv, yv), 3, color='k')
center = Circle((xc, yc), 3, color='r')
circ = Circle((xc, yc), np.abs(R), color='r', fill=False)  # positive R
center1 = Circle((xc1, yc1), 3, color='b')
circ1 = Circle((xc1, yc1), np.abs(R1), color='b', fill=False)  # negative R

center2 = Circle((xd, yd), 3, color='y')
center3 = Circle((xd1, yd1), 3, color='g')

fig, ax = plt.subplots(figsize=(8,8))
ax.add_artist(vertex)
ax.add_artist(center)
ax.add_artist(circ)
ax.add_artist(center1)
ax.add_artist(circ1)
ax.add_artist(center2)
ax.add_artist(center3)
ax.axhline(y=0, alpha=0.5, color='black')
ax.axvline(x=0, alpha=0.5, color='black')
ax.set_xlim((-300, 300))
ax.set_ylim((-300, 300))

plt.show()

# %%
xv, yv = -50, -50
phi = 135
invPt = -0.5

phi_rad = np.deg2rad(phi)
R = -(1.0/(0.003 * 3.8 * invPt))
xc, yc = xv - R * np.sin(phi_rad), yv + R * np.cos(phi_rad)

R1 = -1 * R
xc1, yc1 = xv - R1 * np.sin(phi_rad), yv + R1 * np.cos(phi_rad)

d0 = R - my_sign(R) * np.sqrt(xc*xc + yc*yc)
xd, yd = d0 * np.sin(phi_rad), -d0 * np.cos(phi_rad)
assert(my_sign(d0) == my_sign(xv*np.sin(phi_rad) - yv*np.cos(phi_rad)))

d0_1 = R1 - my_sign(R1) * np.sqrt(xc1*xc1 + yc1*yc1)
xd1, yd1 = d0_1 * np.sin(phi_rad), -d0_1 * np.cos(phi_rad)
assert(my_sign(d0_1) == my_sign(xv*np.sin(phi_rad) - yv*np.cos(phi_rad)))

print R, xc, yc, d0, xd, yd
print R1, xc1, yc1, d0_1, xd1, yd1
# Out:
# 175.438596491 -174.0538212607978 -174.0538212607978 -70.71067811865476 -50.00000000000001 -50.0
# -175.438596491 74.0538212607978 74.05382126079779 -70.71067811865476 -50.00000000000001 -50.0

# %%
from matplotlib.patches import Circle
vertex = Circle((xv, yv), 3, color='k')
center = Circle((xc, yc), 3, color='r')
circ = Circle((xc, yc), np.abs(R), color='r', fill=False)  # positive R
center1 = Circle((xc1, yc1), 3, color='b')
circ1 = Circle((xc1, yc1), np.abs(R1), color='b', fill=False)  # negative R

center2 = Circle((xd, yd), 3, color='y')
center3 = Circle((xd1, yd1), 3, color='g')

fig, ax = plt.subplots(figsize=(8,8))
ax.add_artist(vertex)
ax.add_artist(center)
ax.add_artist(circ)
ax.add_artist(center1)
ax.add_artist(circ1)
ax.add_artist(center2)
ax.add_artist(center3)
ax.axhline(y=0, alpha=0.5, color='black')
ax.axvline(x=0, alpha=0.5, color='black')
ax.set_xlim((-300, 300))
ax.set_ylim((-300, 300))

plt.show()

# %%
xv, yv = -50, 50
phi = 45
invPt = -0.5

phi_rad = np.deg2rad(phi)
R = -(1.0/(0.003 * 3.8 * invPt))
xc, yc = xv - R * np.sin(phi_rad), yv + R * np.cos(phi_rad)

R1 = -1 * R
xc1, yc1 = xv - R1 * np.sin(phi_rad), yv + R1 * np.cos(phi_rad)

d0 = R - my_sign(R) * np.sqrt(xc*xc + yc*yc)
xd, yd = d0 * np.sin(phi_rad), -d0 * np.cos(phi_rad)
assert(my_sign(d0) == my_sign(xv*np.sin(phi_rad) - yv*np.cos(phi_rad)))

d0_1 = R1 - my_sign(R1) * np.sqrt(xc1*xc1 + yc1*yc1)
xd1, yd1 = d0_1 * np.sin(phi_rad), -d0_1 * np.cos(phi_rad)
assert(my_sign(d0_1) == my_sign(xv*np.sin(phi_rad) - yv*np.cos(phi_rad)))

print R, xc, yc, d0, xd, yd
print R1, xc1, yc1, d0_1, xd1, yd1
# Out:
# 175.438596491 -174.0538212607978 174.0538212607978 -70.71067811865476 -50.0 50.00000000000001
# -175.438596491 74.05382126079779 -74.0538212607978 -70.71067811865476 -50.0 50.00000000000001

# %%
from matplotlib.patches import Circle
vertex = Circle((xv, yv), 3, color='k')
center = Circle((xc, yc), 3, color='r')
circ = Circle((xc, yc), np.abs(R), color='r', fill=False)  # positive R
center1 = Circle((xc1, yc1), 3, color='b')
circ1 = Circle((xc1, yc1), np.abs(R1), color='b', fill=False)  # negative R

center2 = Circle((xd, yd), 3, color='y')
center3 = Circle((xd1, yd1), 3, color='g')

fig, ax = plt.subplots(figsize=(8,8))
ax.add_artist(vertex)
ax.add_artist(center)
ax.add_artist(circ)
ax.add_artist(center1)
ax.add_artist(circ1)
ax.add_artist(center2)
ax.add_artist(center3)
ax.axhline(y=0, alpha=0.5, color='black')
ax.axvline(x=0, alpha=0.5, color='black')
ax.set_xlim((-300, 300))
ax.set_ylim((-300, 300))

plt.show()

# %%
xv, yv = 50, -50
phi = 45
invPt = -0.5

phi_rad = np.deg2rad(phi)
R = -(1.0/(0.003 * 3.8 * invPt))
xc, yc = xv - R * np.sin(phi_rad), yv + R * np.cos(phi_rad)

R1 = -1 * R
xc1, yc1 = xv - R1 * np.sin(phi_rad), yv + R1 * np.cos(phi_rad)

d0 = R - my_sign(R) * np.sqrt(xc*xc + yc*yc)
xd, yd = d0 * np.sin(phi_rad), -d0 * np.cos(phi_rad)
assert(my_sign(d0) == my_sign(xv*np.sin(phi_rad) - yv*np.cos(phi_rad)))

d0_1 = R1 - my_sign(R1) * np.sqrt(xc1*xc1 + yc1*yc1)
xd1, yd1 = d0_1 * np.sin(phi_rad), -d0_1 * np.cos(phi_rad)
assert(my_sign(d0_1) == my_sign(xv*np.sin(phi_rad) - yv*np.cos(phi_rad)))

print R, xc, yc, d0, xd, yd
print R1, xc1, yc1, d0_1, xd1, yd1
# Out:
# 175.438596491 -74.05382126079779 74.0538212607978 70.71067811865476 50.0 -50.00000000000001
# -175.438596491 174.0538212607978 -174.0538212607978 70.71067811865476 50.0 -50.00000000000001

# %%
from matplotlib.patches import Circle
vertex = Circle((xv, yv), 3, color='k')
center = Circle((xc, yc), 3, color='r')
circ = Circle((xc, yc), np.abs(R), color='r', fill=False)  # positive R
center1 = Circle((xc1, yc1), 3, color='b')
circ1 = Circle((xc1, yc1), np.abs(R1), color='b', fill=False)  # negative R

center2 = Circle((xd, yd), 3, color='y')
center3 = Circle((xd1, yd1), 3, color='g')

fig, ax = plt.subplots(figsize=(8,8))
ax.add_artist(vertex)
ax.add_artist(center)
ax.add_artist(circ)
ax.add_artist(center1)
ax.add_artist(circ1)
ax.add_artist(center2)
ax.add_artist(center3)
ax.axhline(y=0, alpha=0.5, color='black')
ax.axvline(x=0, alpha=0.5, color='black')
ax.set_xlim((-300, 300))
ax.set_ylim((-300, 300))

plt.show()

# %% [markdown]
# ### Misc (3)

# %%
#xv, yv = 50, 50
phi = 165
invPt = -0.5

rot = -15
d0 = 70.71067811865476

phi_rad = np.deg2rad(phi + rot)
R = -(1.0/(0.003 * 3.8 * invPt))
xd, yd = d0 * np.sin(phi_rad), -d0 * np.cos(phi_rad)
xv, yv = xd, yd
xc, yc = xv - R * np.sin(phi_rad), yv + R * np.cos(phi_rad)

d0_1 = d0
R1 = -1 * R
xd1, yd1 = d0_1 * np.sin(phi_rad), -d0_1 * np.cos(phi_rad)
xc1, yc1 = xv - R1 * np.sin(phi_rad), yv + R1 * np.cos(phi_rad)

#xw = (xv-xc) * np.cos(np.deg2rad(-rot)) - (yv-yc) * np.sin(np.deg2rad(-rot)) + xc
#yw = (xv-xc) * np.sin(np.deg2rad(-rot)) + (yv-yc) * np.cos(np.deg2rad(-rot)) + yc
xw = xc + R * np.sin(np.deg2rad(phi))
yw = yc - R * np.cos(np.deg2rad(phi))
xw1 = xc1 + R1 * np.sin(np.deg2rad(phi))
yw1 = yc1 - R1 * np.cos(np.deg2rad(phi))

print R, xc, yc, d0, xd, yd
print R1, xc1, yc1, d0_1, xd1, yd1
print xw, yw, np.hypot(xw, yw)
# Out:
# 175.438596491 -52.36395918628664 -90.69703779611153 70.7106781187 35.35533905932737 61.23724356957946
# -175.438596491 123.07463730494138 213.17152493527044 70.7106781187 35.35533905932737 61.23724356957946
# -6.957109168300505 78.76363348267235 79.07029358344634

# %%
from matplotlib.patches import Circle
vertex = Circle((xv, yv), 3, color='k')
center = Circle((xc, yc), 3, color='r')
circ = Circle((xc, yc), np.abs(R), color='r', fill=False)  # positive R
center1 = Circle((xc1, yc1), 3, color='b')
circ1 = Circle((xc1, yc1), np.abs(R1), color='b', fill=False)  # negative R

#center2 = Circle((xd, yd), 3, color='y')
#center3 = Circle((xd1, yd1), 3, color='g')

center4 = Circle((xw, yw), 3, color='m')
center5 = Circle((xw1, yw1), 3, color='c')

fig, ax = plt.subplots(figsize=(8,8))
ax.add_artist(vertex)
ax.add_artist(center)
ax.add_artist(circ)
ax.add_artist(center1)
ax.add_artist(circ1)
#ax.add_artist(center2)
#ax.add_artist(center3)
ax.add_artist(center4)
ax.add_artist(center5)
ax.axhline(y=0, alpha=0.5, color='black')
ax.axvline(x=0, alpha=0.5, color='black')
ax.set_xlim((-300, 300))
ax.set_ylim((-300, 300))

plt.show()

# %%
xv, yv = xw, yw
phi = 165
invPt = -0.5

phi_rad = np.deg2rad(phi)
R = -(1.0/(0.003 * 3.8 * invPt))
xc, yc = xv - R * np.sin(phi_rad), yv + R * np.cos(phi_rad)

xv, yv = xw1, yw1
R1 = -1 * R
xc1, yc1 = xv - R1 * np.sin(phi_rad), yv + R1 * np.cos(phi_rad)

d0 = R - my_sign(R) * np.sqrt(xc*xc + yc*yc)
phi_d_rad = np.deg2rad(phi + rot)
xd, yd = d0 * np.sin(phi_d_rad), -d0 * np.cos(phi_d_rad)
#assert(my_sign(d0) == my_sign(xv*np.sin(phi_rad) - yv*np.cos(phi_rad)))

d0_1 = R1 - my_sign(R1) * np.sqrt(xc1*xc1 + yc1*yc1)
xd1, yd1 = d0_1 * np.sin(phi_d_rad), -d0_1 * np.cos(phi_d_rad)
#assert(my_sign(d0_1) == my_sign(xv*np.sin(phi_rad) - yv*np.cos(phi_rad)))

print R, xc, yc, d0, xd, yd
print R1, xc1, yc1, d0_1, xd1, yd1
# Out:
# 175.438596491 -52.36395918628664 -90.69703779611153 70.71067811865476 35.35533905932737 61.23724356957946
# -175.438596491 123.07463730494138 213.17152493527044 70.71067811865476 35.35533905932737 61.23724356957946

# %%
from matplotlib.patches import Circle
vertex = Circle((xv, yv), 3, color='k')
center = Circle((xc, yc), 3, color='r')
circ = Circle((xc, yc), np.abs(R), color='r', fill=False)  # positive R
center1 = Circle((xc1, yc1), 3, color='b')
circ1 = Circle((xc1, yc1), np.abs(R1), color='b', fill=False)  # negative R

center2 = Circle((xd, yd), 3, color='y')
center3 = Circle((xd1, yd1), 3, color='g')

fig, ax = plt.subplots(figsize=(8,8))
ax.add_artist(vertex)
ax.add_artist(center)
ax.add_artist(circ)
ax.add_artist(center1)
ax.add_artist(circ1)
ax.add_artist(center2)
ax.add_artist(center3)
ax.axhline(y=0, alpha=0.5, color='black')
ax.axvline(x=0, alpha=0.5, color='black')
ax.set_xlim((-300, 300))
ax.set_ylim((-300, 300))

plt.show()
