# %%
import os
import sys
os.environ['KERAS_BACKEND'] = 'tensorflow'

import numpy as np
from keras import backend as K
import tensorflow as tf

import matplotlib.pyplot as plt
import matplotlib.colors as colors
# Out:
# Using TensorFlow backend.

# %%
from keras.losses import mean_squared_error, mean_absolute_error, binary_crossentropy

def huber_loss(y_true, y_pred, delta=1.345):
  x = K.abs(y_true - y_pred)
  squared_loss = 0.5*K.square(x)
  absolute_loss = delta * (x - 0.5*delta)
  xx = tf.where(x < delta, squared_loss, absolute_loss)  # needed for tensorflow
  return K.mean(xx, axis=-1)

def weighted_crossentropy(target, output, pos_weight, from_logits=False):
  # Note: tf.nn.sigmoid_cross_entropy_with_logits
  # expects logits, Keras expects probabilities.
  if not from_logits:
    # transform back to logits
    _epsilon = tf.convert_to_tensor(K.epsilon(), dtype=output.dtype.base_dtype)
    output = tf.clip_by_value(output, _epsilon, 1 - _epsilon)
    output = tf.log(output / (1 - output))
  return tf.nn.weighted_cross_entropy_with_logits(targets=target, logits=output, pos_weight=pos_weight)

def my_binary_crossentropy(y_true, y_pred, mask_value=100., pos_weight=0.333333):
  #xx = K.binary_crossentropy(y_true, y_pred)
  xx = weighted_crossentropy(y_true, y_pred, pos_weight=pos_weight) * 2/(1+pos_weight)
  return K.mean(xx, axis=-1)

# %%
# Prepare data
n = 126029

# Random numbers between -0.5 and 0.5
y_true = -0.5 + np.random.rand(n)

# d(q/pT) ~ 0.02
y_meas = 0.02 * np.random.randn(n)
y_meas += y_true

reg_pt_scale = 100.
y_true_1 = y_true * reg_pt_scale
y_meas_1 = y_meas * reg_pt_scale

# %%
# Find losses
sess = K.get_session()

loss1 = mean_squared_error(y_true_1[:,np.newaxis], y_meas_1[:,np.newaxis]).eval(session=sess)
loss2 = mean_absolute_error(y_true_1[:,np.newaxis], y_meas_1[:,np.newaxis]).eval(session=sess)
loss3 = huber_loss(y_true_1[:,np.newaxis], y_meas_1[:,np.newaxis]).eval(session=sess)
loss4 = huber_loss(y_true_1[:,np.newaxis], y_meas_1[:,np.newaxis], delta=2).eval(session=sess)

# %%
# Styling
plt.style.use('tdrstyle.mplstyle')

# %% [raw]
# plt.figure()
#
# #plt.hist(np.random.randn(n), bins=40)
# plt.hist(y_true, bins=40)
#
# plt.show()

# %%
plt.figure()

diff = y_true - y_meas

hist, edges, _ = plt.hist(diff, bins=120, range=(-0.3,0.3), histtype='stepfilled', facecolor='g', alpha=0.6)
plt.xlabel(r'$\Delta(q/p_{T})_{\mathrm{meas-true}}$ [1/GeV]')
plt.ylabel(r'entries')

from scipy.optimize import curve_fit

def gaus(x,a,mu,sig):
  return a*np.exp(-0.5*np.square((x-mu)/sig))

def fit_gaus(hist, edges, mu=0., sig=1.):
  hist = hist.astype('float64')
  edges = edges.astype('float64')
  xdata = (edges[1:] + edges[:-1])/2
  ydata = hist
  popt, pcov = curve_fit(gaus, xdata, ydata, p0=[np.max(hist),mu,sig])
  if not np.isfinite(pcov).all():
    raise Exception('Fit has failed to converge.')
  return popt

popt = fit_gaus(hist, edges, mu=0, sig=0.2)
print('gaus fit (a, mu, sig): {0}'.format(popt))
xdata = (edges[1:] + edges[:-1])/2
plt.plot(xdata, gaus(xdata, popt[0], popt[1], popt[2]), color='g')

plt.show()
# Out:
# gaus fit (a, mu, sig): [ 1.24967054e+04 -1.00823140e-05  2.01201025e-02]

# %%
plt.figure()

plt.scatter(diff, loss1)
plt.scatter(diff, loss2)
plt.scatter(diff, loss3)
plt.scatter(diff, loss4)

plt.legend(['mse', 'mae', 'huber', 'huber*'])
plt.show()

# %%
# Find binary crossentropy losses
z0 = np.zeros(n)
z1 = np.ones(n)
z = np.random.rand(n)

z0 = K.cast(z0, dtype=np.float32)
z1 = K.cast(z1, dtype=np.float32)
z = K.cast(z, dtype=np.float32)

zloss1 = binary_crossentropy(z0[:,np.newaxis], z[:,np.newaxis]).eval(session=sess)
zloss2 = binary_crossentropy(z1[:,np.newaxis], z[:,np.newaxis]).eval(session=sess)
zloss3 = my_binary_crossentropy(z0[:,np.newaxis], z[:,np.newaxis]).eval(session=sess)
zloss4 = my_binary_crossentropy(z1[:,np.newaxis], z[:,np.newaxis]).eval(session=sess)

z0 = z0.eval(session=sess)
z1 = z1.eval(session=sess)
z = z.eval(session=sess)

# %%
plt.figure()

plt.scatter(z, zloss1)
plt.scatter(z, zloss2)
#plt.scatter(z, zloss3)
#plt.scatter(z, zloss4)

plt.legend(['bc1', 'bc2', 'bc3', 'bc4'])
plt.show()

# %%
# Find custom log losses
def log_loss1(y_true, y_pred):
  discr_pt_cut = 14.
  reg_pt_scale = 100.
  log_loss_weight = 1
  
  # Use y = 1
  # Sigmoid: 1/(1+e^(-x))
  # Negative log of sigmoid: log(1+e^(-x))
  x_pu = K.abs(y_pred) - reg_pt_scale/discr_pt_cut
  log_loss = K.log(1+K.exp(-x_pu))
  return K.mean(log_loss, axis=-1)

def log_loss2(y_true, y_pred):
  discr_pt_cut = 14.
  reg_pt_scale = 100.
  log_loss_weight = 1
  
  # Use y = 0
  # Sigmoid: 1/(1+e^(-x))
  # 1-sigmoid: 1/(1+e^x)
  # Negative log of 1-sigmoid: log(1+e^(x)) = x + log(1+e^(-x))
  x_pu = K.abs(reg_pt_scale/y_pred) - discr_pt_cut
  x_pu = K.clip(x_pu, 0, 1000)
  log_loss = x_pu + K.log(1+K.exp(-x_pu))
  log_loss_weight = 0.01
  log_loss *= log_loss_weight
  return K.mean(log_loss, axis=-1)

lloss1 = log_loss1(y_true_1[:,np.newaxis], y_true_1[:,np.newaxis]).eval(session=sess)
lloss2 = log_loss2(y_true_1[:,np.newaxis], y_true_1[:,np.newaxis]).eval(session=sess)

# %%
plt.figure()

plt.scatter(y_true, lloss1)
plt.scatter(y_true, lloss2)

plt.legend(['ll1', 'll2', 'll3', 'll4'])
plt.show()

# %% [markdown]
# ### Check PU tracks (Trial 1)

# %%
infile = 'mykeras10_out.0.npz'
loaded = np.load(infile)

pu_y_true  = loaded['pu_y_true']
pu_y_label = loaded['pu_y_label']
pu_y_meas  = loaded['pu_y_meas']
pu_y_discr = loaded['pu_y_discr']
pu_x       = loaded['pu_x']
pu_x_mask  = loaded['pu_x_mask']
pu_x_road  = loaded['pu_x_road']
pu_aux     = loaded['pu_aux']

pu_highest_part_pt = pu_aux[:,2].copy()
pu_highest_part_pt = np.where(np.isnan(pu_highest_part_pt), 0., pu_highest_part_pt)
pu_highest_part_y = np.where(pu_highest_part_pt == 0, -0.5, np.abs(1.0/pu_highest_part_pt))

pu_x_theta_median = pu_x_road[:,2].copy()

assert(pu_x_mask.shape[1] == 16)
pu_x_mask_36 = np.ones_like(pu_x, dtype=np.bool)  
pu_x_mask_36[:, 0:12] = np.hstack((pu_x_mask[:,0:12],))
pu_x_mask_36[:, 12:24] = np.hstack((pu_x_mask[:,0:12],))
pu_x_mask_36[:, 24:30] = np.hstack((pu_x_mask[:,0:5], pu_x_mask[:,11:12]))
pu_x_mask_36[:, 30:36] = np.hstack((pu_x_mask[:,0:5], pu_x_mask[:,11:12]))

print pu_x.shape, pu_x_mask_36.shape, pu_y_meas.shape, pu_highest_part_pt.shape, pu_highest_part_y.shape
# Out:
# /cvmfs/cms.cern.ch/slc6_amd64_gcc700/external/py2-ipykernel/4.9.0-ikaegh/lib/python2.7/site-packages/ipykernel_launcher.py:15: RuntimeWarning: divide by zero encountered in divide
#   from ipykernel import kernelapp as app
# (1135956, 36) (1135956, 36) (1135956, 1) (1135956,) (1135956,)

# %%
fig, ax = plt.subplots(figsize=(3.5,3.5))
ax.hist(pu_highest_part_pt, bins=100, range=(0.,100.), histtype='step', color='b', linewidth=2)
ax.hist(np.abs(1.0/pu_y_meas), bins=100, range=(0.,100.), histtype='step', color='orange', linewidth=2)
ax.set_yscale('log')
ax.set_ylim(1,2e6)
plt.show()

# %%
fig, ax = plt.subplots(figsize=(3.5,3.5))
ax.hist(pu_y_discr, bins=100, range=(0,1), histtype='step', color='orange', linewidth=2)
ax.set_yscale('log')
ax.set_ylim(1,2e6)
plt.show()

# %%
fig, ax = plt.subplots(figsize=(3.5,3.5))
ax.hist2d(np.abs(1.0/pu_y_meas)[:, 0], pu_highest_part_pt, bins=100, range=((0.,100.),(0.,100.)),
          norm=colors.LogNorm(vmin=1, vmax=2e6), cmap=plt.cm.viridis,)
plt.show()

# %%
fig, ax = plt.subplots(figsize=(3.5,3.5))
ax.hist2d(np.abs(pu_y_meas)[:, 0], pu_highest_part_y, bins=100, range=((0.,0.6),(0.,1.)),
          norm=colors.LogNorm(vmin=1, vmax=2e6), cmap=plt.cm.viridis,)
plt.show()

# %%
fig, ax = plt.subplots(figsize=(3.5,3.5))
ax.hist2d((pu_y_discr)[:, 0], pu_highest_part_pt, bins=100, range=((0.,1.),(0.,100.)),
          norm=colors.LogNorm(vmin=1, vmax=2e6), cmap=plt.cm.viridis,)
plt.show()

# %%
fig, ax = plt.subplots(figsize=(3.5,3.5))
ax.hist2d((pu_y_discr)[:, 0], pu_highest_part_y, bins=100, range=((0.,1.),(0.,0.6)),
          norm=colors.LogNorm(vmin=1, vmax=2e6), cmap=plt.cm.viridis,)
plt.show()

# %%
fig, ax = plt.subplots(figsize=(3.5,3.5))
ax.hist2d((pu_y_discr)[:, 0], np.abs(1.0/pu_y_meas)[:, 0], bins=100, range=((0.,1.),(0.,100.)),
          norm=colors.LogNorm(vmin=1, vmax=2e6), cmap=plt.cm.viridis,)
plt.show()

# %%
fig, ax = plt.subplots(figsize=(3.5,3.5))
ax.hist2d((pu_y_discr)[:, 0], np.abs(pu_y_meas)[:, 0], bins=100, range=((0.,1.),(0.,0.6)),
          norm=colors.LogNorm(vmin=1, vmax=2e6), cmap=plt.cm.viridis,)
plt.show()

# %% [raw]
# from six.moves import range, zip, map, filter
#
# for ievt, (x, x_mask, x_road, y_meas, y_discr, aux) in enumerate(zip(pu_x, pu_x_mask, pu_x_road, pu_y_meas, pu_y_discr, pu_aux)):
#   (jobid, ievt, highest_part_pt, highest_track_pt) = aux
#   #print ievt, aux, y_meas, y_discr

# %% [raw]
# fig, axs = plt.subplots(36/6, 6, figsize=(6,6))
#
# for i in xrange(36):
#   x_i = pu_x[:, i].copy()
#
#   if 12 <= i < 24:
#     x_i -= pu_x_theta_median
#
#   x_mask_i = pu_x_mask_36[:, i]
#   valid = ~x_mask_i
#
#   xmin, xmax = np.percentile(x_i, q=[1,99])
#   ymin, ymax = 0, 0.6
#   _range = [[xmin, xmax], [ymin, ymax]]
#
#   ax = axs[(i/6, i%6)]
#   ax.hist2d(x_i[valid], pu_highest_part_y[valid], bins=40, range=_range, cmap=plt.cm.viridis)
#   ax.set_xticklabels([])
#   ax.set_yticklabels([])
#
# plt.show()

# %% [markdown]
# ### Check PU tracks (Trial 2)

# %%
infile = 'mykeras10_out.1.npz'
loaded = np.load(infile)

pu_y_true  = loaded['pu_y_true']
pu_y_label = loaded['pu_y_label']
pu_y_meas  = loaded['pu_y_meas']
pu_y_discr = loaded['pu_y_discr']
pu_x       = loaded['pu_x']
pu_x_mask  = loaded['pu_x_mask']
pu_x_road  = loaded['pu_x_road']
pu_aux     = loaded['pu_aux']

pu_highest_part_pt = pu_aux[:,2].copy()
pu_highest_part_pt = np.where(np.isnan(pu_highest_part_pt), 0., pu_highest_part_pt)
pu_highest_part_y = np.where(pu_highest_part_pt == 0, -0.5, np.abs(1.0/pu_highest_part_pt))

pu_x_theta_median = pu_x_road[:,2].copy()

assert(pu_x_mask.shape[1] == 16)
pu_x_mask_36 = np.ones_like(pu_x, dtype=np.bool)  
pu_x_mask_36[:, 0:12] = np.hstack((pu_x_mask[:,0:12],))
pu_x_mask_36[:, 12:24] = np.hstack((pu_x_mask[:,0:12],))
pu_x_mask_36[:, 24:30] = np.hstack((pu_x_mask[:,0:5], pu_x_mask[:,11:12]))
pu_x_mask_36[:, 30:36] = np.hstack((pu_x_mask[:,0:5], pu_x_mask[:,11:12]))

print pu_x.shape, pu_x_mask_36.shape, pu_y_meas.shape, pu_highest_part_pt.shape, pu_highest_part_y.shape
# Out:
# /cvmfs/cms.cern.ch/slc6_amd64_gcc700/external/py2-ipykernel/4.9.0-ikaegh/lib/python2.7/site-packages/ipykernel_launcher.py:15: RuntimeWarning: divide by zero encountered in divide
#   from ipykernel import kernelapp as app
# (1135956, 36) (1135956, 36) (1135956, 1) (1135956,) (1135956,)

# %%
fig, ax = plt.subplots(figsize=(3.5,3.5))
ax.hist(pu_highest_part_pt, bins=100, range=(0.,100.), histtype='step', color='b', linewidth=2)
ax.hist(np.abs(1.0/pu_y_meas), bins=100, range=(0.,100.), histtype='step', color='orange', linewidth=2)
ax.set_yscale('log')
ax.set_ylim(1,2e6)
plt.show()

# %%
fig, ax = plt.subplots(figsize=(3.5,3.5))
ax.hist(pu_y_discr, bins=100, range=(0,1), histtype='step', color='orange', linewidth=2)
ax.set_yscale('log')
ax.set_ylim(1,2e6)
plt.show()

# %%
fig, ax = plt.subplots(figsize=(3.5,3.5))
ax.hist2d(np.abs(1.0/pu_y_meas)[:, 0], pu_highest_part_pt, bins=100, range=((0.,100.),(0.,100.)),
          norm=colors.LogNorm(vmin=1, vmax=2e6), cmap=plt.cm.viridis,)
plt.show()

# %%
fig, ax = plt.subplots(figsize=(3.5,3.5))
ax.hist2d(np.abs(pu_y_meas)[:, 0], pu_highest_part_y, bins=100, range=((0.,0.6),(0.,1.)),
          norm=colors.LogNorm(vmin=1, vmax=2e6), cmap=plt.cm.viridis,)
plt.show()

# %%
fig, ax = plt.subplots(figsize=(3.5,3.5))
ax.hist2d((pu_y_discr)[:, 0], pu_highest_part_pt, bins=100, range=((0.,1.),(0.,100.)),
          norm=colors.LogNorm(vmin=1, vmax=2e6), cmap=plt.cm.viridis,)
plt.show()

# %%
fig, ax = plt.subplots(figsize=(3.5,3.5))
ax.hist2d((pu_y_discr)[:, 0], pu_highest_part_y, bins=100, range=((0.,1.),(0.,0.6)),
          norm=colors.LogNorm(vmin=1, vmax=2e6), cmap=plt.cm.viridis,)
plt.show()

# %%
fig, ax = plt.subplots(figsize=(3.5,3.5))
ax.hist2d((pu_y_discr)[:, 0], np.abs(1.0/pu_y_meas)[:, 0], bins=100, range=((0.,1.),(0.,100.)),
          norm=colors.LogNorm(vmin=1, vmax=2e6), cmap=plt.cm.viridis,)
plt.show()

# %%
fig, ax = plt.subplots(figsize=(3.5,3.5))
ax.hist2d((pu_y_discr)[:, 0], np.abs(pu_y_meas)[:, 0], bins=100, range=((0.,1.),(0.,0.6)),
          norm=colors.LogNorm(vmin=1, vmax=2e6), cmap=plt.cm.viridis,)
plt.show()
