# %%
from ROOT import TFile
# Out:
# Welcome to JupyROOT 6.14/09

# %%
f = TFile("ntuple_SingleMuon_Displaced_2GeV_PhaseIITDRSpring19_add.8.root")

# %%
f.ls()
# Out:
# TFile**		ntuple_SingleMuon_Displaced_2GeV_PhaseIITDRSpring19_add.8.root
#  TFile*		ntuple_SingleMuon_Displaced_2GeV_PhaseIITDRSpring19_add.8.root
#   KEY: TDirectoryFile	ntupler;1	ntupler

# %%
t = f.Get("ntupler/tree")

# %%
type(t)
# Out:
# ROOT.TTree

# %%
t.Print()
# Out:
# ******************************************************************************
# *Tree    :tree      : tree                                                   *
# *Entries :  1998000 : Total =      5075698289 bytes  File  Size = 1951189310 *
# *        :          : Tree compression factor =   2.60                       *
# ******************************************************************************
# *Br    0 :vh_endcap : vector<short>                                          *
# *Entries :  1998000 : Total  Size=   52700149 bytes  File Size  =    9770455 *
# *Baskets :     1998 : Basket Size=      32000 bytes  Compression=   5.39     *
# *............................................................................*
# *Br    1 :vh_station : vector<short>                                         *
# *Entries :  1998000 : Total  Size=   52702151 bytes  File Size  =   15625736 *
# *Baskets :     1998 : Basket Size=      32000 bytes  Compression=   3.37     *
# ...

# %%
for evt in t:
  for hit in evt.
